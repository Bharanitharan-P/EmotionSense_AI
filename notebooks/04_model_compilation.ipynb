# %% [markdown]
# # 04 Model Compilation
#
# This notebook compiles the EfficientNetB0 model created in
# 03_model_building.ipynb.
#
# Configuration:
# - Optimizer : Adam
# - Learning Rate : 0.001
# - Loss Function : Categorical Crossentropy
# - Metric : Accuracy
#
# Note:
# Run 03_model_building.ipynb before executing this notebook.

# %%
from tensorflow.keras.optimizers import Adam
print("Optimizer Imported Successfully!")
# Out:
# Optimizer Imported Successfully!
